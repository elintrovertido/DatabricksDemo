# %%
print("Hello World")

# %%
# %sql
SELECT "SANTHOSH" AS NAME;

# %%
# %run ./Variables

# %%
full_name

# %%
# %fs ls '/databricks-datasets'

# %%
files = dbutils.fs.ls('/databricks-datasets/')
display(files)

# %%
a = 3
b = 5
a+b
